# %%
import librosa
import librosa.display
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np
import scipy

# %%
x, sr = librosa.load("audio/c_strum.wav")
ipd.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(15,5))
librosa.display.waveshow(x, sr, alpha=0.8)
# Out:
# /var/folders/hv/hjk953ts2kl_rzsyst_tp9x00000gn/T/ipykernel_893/1013077135.py:2: FutureWarning: Pass sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   librosa.display.waveshow(x, sr, alpha=0.8)

# %%
T = 2.0
f0 = 1047.0 
sr = 22050 
t = np.linspace(0, T, int(T*sr), endpoint=False)
x = 0.1*np.sin(2*np.pi*f0*t)
ipd.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
X = scipy.fft.fft(x[:4096])
X_mag = np.absolute(X)
f = np.linspace(0, sr, 4096)
plt.figure(figsize=(15,5))
plt.plot(f[:2000], X_mag[:2000])
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 X = scipy.fft.fft(x[:4096])
#       2 X_mag = np.absolute(X)
#       3 f = np.linspace(0, sr, 4096)
#
# NameError: name 'scipy' is not defined
